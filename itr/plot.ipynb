# %%
import pandas as pd
df = pd.read_csv('/home/nmduy/PiToMe/coco_ots.csv')

# %%
df
# Out:
#     Unnamed: 0  test/r1_i2t  test/r5_i2t  test/r10_i2t  test/r_i2t  \
# 0            0        46.70        70.82         80.14      197.66
# 1            0        48.66        74.14         82.60      205.40
# 2            0        50.80        75.44         83.68      209.92
# 3            0        52.12        76.78         84.22      213.12
# 4            0        43.64        68.66         78.00      190.30
# ..         ...          ...          ...           ...         ...
# 59           0        68.96        91.20         95.86      256.02
# 60           0        74.34        94.26         97.42      266.02
# 61           0        74.34        94.26         97.42      266.02
# 62           0        74.34        94.26         97.42      266.02
# 63           0        74.34        94.26         97.42      266.02
#
#     test/r1_t2i  test/r5_t2i  test/r10_t2i  test/r_t2i  test/r_all  \
# 0     29.432227    53.874450     65.177929  148.484606  346.144606
# 1     30.995602    55.861655     67.017193  153.874450  359.274450
# 2     32.123151    57.165134     67.912835  157.201120  367.121120
# 3     32.830868    58.080768     68.852459  159.764094  372.884094
# 4     27.013195    50.647741     62.227109  139.888045  330.188045
# ..          ...          ...           ...         ...         ...
# 59    59.260296    83.550580     90.031987  232.842863  488.862863
# 60    63.514594    86.081567     91.847261  241.443423  507.463423
# 61    63.514594    86.081567     91.847261  241.443423  507.463423
# 62    63.514594    86.081567     91.847261  241.443423  507.463423
# 63    63.514594    86.081567     91.847261  241.443423  507.463423
#
#     eval memory      gflops  sample/sec    algo   model  epoch
# 0      0.609560   10.496009   89.326684  PiToMe  CLIP_B    NaN
# 1      0.690355   11.913403   89.898065  PiToMe  CLIP_B    NaN
# 2      0.779188   13.483668   87.195999  PiToMe  CLIP_B    NaN
# 3      0.888748   15.439109   85.147940  PiToMe  CLIP_B    NaN
# 4      0.609560   10.496009   91.669951    ToMe  CLIP_B    NaN
# ..          ...         ...         ...     ...     ...    ...
# 59     0.654888  434.503588   13.039361     dct   BLIP2    0.0
# 60     1.000000  678.451488   10.089823    none   BLIP2    0.0
# 61     1.000000  678.451488   10.095769    none   BLIP2    0.0
# 62     1.000000  678.451488   10.100839    none   BLIP2    0.0
# 63     1.000000  678.451488   10.091924    none   BLIP2    0.0
#
# [64 rows x 16 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
custom_marker = {'none':'o','PiToMe':'x', 'ToMe':'+', 'dct': 's'}
custom_color = {'none':'gray','PiToMe':'red', 'ToMe':'blue', 'dct': 'green'}

# Draw a line plot
sns.lineplot(
    x='gflops', 
    y='test/r_all', 
    style='model',
    hue='algo',
    data=df[df['algo'].isin(['PiToMe', 'ToMe','dct'])], 
    markers=True, 
    # dashes=True,
    # markers=custom_marker,
    palette=custom_color,
)

sns.lineplot(
    x='gflops', 
    y='test/r_all', 
    style='model',
    hue='algo',
    data=df[df['algo']=='none'], 
    markers=True, 
    markersize=10,
    palette=custom_color,
)
plt.xscale('log')
plt.yscale('log')
# plt.text(df.loc[df['algo'] == 'baseline', 'gflops'].values[0],
        #  df.loc[df['algo'] == 'baseline', 'test/r_all'].values[0],
        #  'CLIP-B',
        #  fontsize=12,
        #  color='black',
        #  ha='right', va='bottom')

# Add text to the plot

# Show the plot
plt.show()

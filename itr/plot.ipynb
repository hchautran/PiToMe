# %%
import pandas as pd
df = pd.read_csv('/home/caduser/HDD/vit_token_compress/PiToMe/coco_use_k.csv')

# %%
df.loc[df['algo']=='none', 'algo'] = 'baseline'

# %%
df
# Out:
#     Unnamed: 0  test/r1_i2t  test/r5_i2t  test/r10_i2t  test/r_i2t  \
# 0            0        52.04        76.80         84.26      213.10
# 1            0        50.50        75.16         83.26      208.92
# 2            0        48.80        73.56         82.20      204.56
# 3            0        44.26        68.80         78.14      191.20
# 4            0        49.62        73.42         82.38      205.42
# ..         ...          ...          ...           ...         ...
# 57           0        73.40        93.98         97.24      264.62
# 58           0        37.26        65.66         76.60      179.52
# 59           0        57.64        85.38         92.54      235.56
# 60           0        67.30        91.32         95.82      254.44
# 61           0        72.42        93.70         96.96      263.08
#
#     test/r1_t2i  test/r5_t2i  test/r10_t2i  test/r_t2i  test/r_all  \
# 0     32.798880    58.100760     68.848461  159.748101  372.848101
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, MultipleLocator
# Sample data
# custom_marker = {'baseline':'o','PiToMe':'x', 'ToMe':'+', 'dct': 's'}
# custom_color = {'baseline':'gray','PiToMe':'red', 'ToMe':'blue', 'dct': 'green'}

sns.set(style="darkgrid")
# Draw a line plot
sns.lineplot(
    x='gflops', 
    y='test/r_all', 
    style='model',
    hue='use k',
    data=df[df['algo'].isin(['ToMe'])], 
    markers=True, 
    # dashes=True,
    # markersize=6,
    # markers=custom_marker,
    # ci=None,  # Disable confidence intervals for a cleaner plot
    # palette=custom_color,
    # label='algo'
)

plt.xscale('log')
# plt.yscale('log')
# plt.text(df.loc[df['algo'] == 'baseline', 'gflops'].values[0],
        #  df.loc[df['algo'] == 'baseline', 'test/r_all'].values[0],
        #  'CLIP-B',
        #  fontsize=12,
        #  color='black',
        #  ha='right', va='bottom')

# Add text to the plot
# plt.title('Comparison of Algorithms')
plt.xlabel('FLOPS')
plt.ylabel('RSum')
# Add gridlines
# plt.grid(color='gray', linestyle='--', linewidth=0.5)

# Format x-axis ticks to display actual values
plt.gca().xaxis.set_major_formatter(ScalarFormatter())
plt.gca().xaxis.set_major_locator(MultipleLocator(200))
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %%
import pandas as pd
df = pd.read_csv('/home/caduser/HDD/vit_token_compress/PiToMe/mae_use_k.csv')

# %%
new_column_names = {'usr_k': 'use k'}
df.rename(columns=new_column_names, inplace=True)

# %%
# df.loc[df['flops'] < 1.5, 'model'] = 'DeiT-T-16'
# df.loc[(df['flops'] > 1.5) & (df['flops'] < 4.2), 'model'] = 'DeiT-S-16'
# df[df['flops'] > 6, 'model'] = 'DeiT-B-16'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, MultipleLocator
# Sample data
custom_marker = {'baseline':'o','PiToMe':'x', 'ToMe':'+', 'DiffRate': 's'}
custom_color = {'baseline':'gray','PiToMe':'red', 'ToMe':'blue', 'DiffRate': 'green'}

sns.set(style="darkgrid")
# Draw a line plot
sns.lineplot(
    x='flops', 
    y='acc1', 
    style='model',
    hue='use k',
    # data=df[df['algo'].isin(['PiToMe', 'ToMe','DiffRate', 'baseline'])], 
    data=df[df['algo'].isin(['ToMe'])], 
    markers=True, 
    dashes=True,
    # markersize=7,
    # markers=custom_marker,
    # ci=None,  # Disable confidence intervals for a cleaner plot
    # palette=custom_color,
    # label='algo'
)

plt.xscale('log')
# plt.yscale('log')
# plt.text(df.loc[df['algo'] == 'baseline', 'gflops'].values[0],
        #  df.loc[df['algo'] == 'baseline', 'test/r_all'].values[0],
        #  'CLIP-B',
        #  fontsize=12,
        #  color='black',
        #  ha='right', va='bottom')

# Add text to the plot
# plt.title('Comparison of Algorithms')
plt.xlabel('FLOPS')
plt.ylabel('Accuracy')
# Add gridlines
# plt.grid(color='gray', linestyle='--', linewidth=0.5)

# Format x-axis ticks to display actual values
plt.gca().xaxis.set_major_formatter(ScalarFormatter())
plt.gca().xaxis.set_major_locator(MultipleLocator(40))
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %%
import pandas as pd
df = pd.read_csv('/home/caduser/HDD/vit_token_compress/PiToMe/flickr_ots.csv')

# %%
df
# Out:
#     Unnamed: 0  test/r1_i2t  test/r5_i2t  test/r10_i2t  test/r_i2t  \
# 0            0         76.4         92.6          96.0       265.0
# 1            0         79.3         95.6          98.3       273.2
# 2            0         81.5         96.6          98.3       276.4
# 3            0         81.9         96.5          98.9       277.3
# 4            0         69.7         90.8          94.8       255.3
# 5            0         74.9         94.4          97.0       266.3
# 6            0         76.9         95.3          97.5       269.7
# 7            0         79.5         95.1          97.6       272.2
# 8            0         52.7         77.4          83.8       213.9
# 9            0         60.1         83.6          90.2       233.9
# 10           0         67.6         88.0          93.2       248.8
# 11           0         70.1         90.1          94.4       254.6
# 12           0         82.4         96.6          98.8       277.8
# 13           0         62.3         84.8          89.7       236.8
# 14           0         76.5         94.5          97.5       268.5
# 15           0         82.7         96.4          99.0       278.1
# 16           0         84.2         97.6          99.0       280.8
# 17           0         52.6         77.2          84.4       214.2
# 18           0         70.4         91.5          95.1       257.0
# 19           0         78.4         95.4          98.1       271.9
# 20           0         83.4         97.0          98.8       279.2
# 21           0         12.4         27.2          36.9        76.5
# 22           0         35.1         61.7          70.9       167.7
# 23           0         60.5         84.4          90.6       235.5
# 24           0         71.4         92.4          96.3       260.1
# 25           0         85.2         97.3          99.3       281.8
# 26           0         90.9         98.6          99.5       289.0
# 27           0         92.1         99.6         100.0       291.7
# 28           0         93.7         99.6          99.8       293.1
# 29           0         94.8         99.5          99.9       294.2
# 30           0         78.8         94.8          97.7       271.3
# 31           0         84.0         95.9          98.1       278.0
# 32           0         88.2         97.9          99.0       285.1
# 33           0         91.4         98.6          99.5       289.5
# 34           0         58.0         80.2          87.1       225.3
# 35           0         67.8         86.9          92.2       246.9
# 36           0         67.6         88.0          92.2       247.8
# 37           0         71.4         92.5          95.6       259.5
# 38           0         94.4         99.6         100.0       294.0
# 39           0         56.2         83.3          89.4       228.9
# 40           0         79.5         96.4          98.8       274.7
# 41           0         88.4         99.7         100.0       288.1
# 42           0         90.1         99.5         100.0       289.6
# 43           0         53.6         81.2          89.5       224.3
# 44           0         73.9         94.8          97.6       266.3
# 45           0         85.3         99.0          99.6       283.9
# 46           0         90.0         99.4          99.9       289.3
# 47           0         13.2         28.5          37.4        79.1
# 48           0         31.4         56.9          68.4       156.7
# 49           0         70.8         91.8          96.3       258.9
# 50           0         86.2         98.7          99.4       284.3
# 51           0         90.8         99.6          99.9       290.3
#
#     test/r1_t2i  test/r5_t2i  test/r10_t2i  test/r_t2i  test/r_all  \
# 0         57.70        81.42         88.10      227.22      492.22
# 1         60.48        84.70         90.82      236.00      509.20
# 2         61.38        85.36         91.36      238.10      514.50
# 3         62.02        85.66         91.86      239.54      516.84
# 4         53.36        78.86         85.76      217.98      473.28
# 5         57.06        82.82         89.46      229.34      495.64
# 9      0.690355   11.913403   99.154116       dct  CLIP_B    NaN
# 10     0.779188   13.483668   95.975418       dct  CLIP_B    NaN
# 11     0.888748   15.439109   90.785677       dct  CLIP_B    NaN
# 12     1.000000   17.447455   94.461800  baseline  CLIP_B    NaN
# 13     0.396239   31.483458   76.137912    PiToMe  CLIP_L    NaN
# 14     0.482166   38.364660   71.501080    PiToMe  CLIP_L    NaN
# 15     0.604734   48.250307   65.036219    PiToMe  CLIP_L    NaN
# 16     0.778696   62.452144   56.607717    PiToMe  CLIP_L    NaN
# 17     0.396239   31.483458   77.315585      ToMe  CLIP_L    NaN
# 18     0.482166   38.364660   71.467391      ToMe  CLIP_L    NaN
# 19     0.604734   48.250307   64.460235      ToMe  CLIP_L    NaN
# 20     0.778696   62.452144   57.752738      ToMe  CLIP_L    NaN
# 21     0.396239   31.483458   73.468999       dct  CLIP_L    NaN
# 22     0.482166   38.364660   67.743650       dct  CLIP_L    NaN
# 23     0.604734   48.250307   60.764837       dct  CLIP_L    NaN
# 24     0.778696   62.452144   52.515714       dct  CLIP_L    NaN
# 25     1.000000   80.857842   49.673920  baseline  CLIP_L    NaN
# 26     0.602253   32.017911   68.700178    PiToMe    BLIP    NaN
# 27     0.678654   36.280856   65.090264    PiToMe    BLIP    NaN
# 28     0.770075   41.487277   61.187979    PiToMe    BLIP    NaN
# 29     0.876950   47.729710   57.067692    PiToMe    BLIP    NaN
# 30     0.602253   32.017911   68.992204      ToMe    BLIP    NaN
# 31     0.678654   36.280856   65.492037      ToMe    BLIP    NaN
# 32     0.770075   41.487277   61.483653      ToMe    BLIP    NaN
# 33     0.876950   47.729710   57.504603      ToMe    BLIP    NaN
# 34     0.602253   32.017911   64.800017       dct    BLIP    NaN
# 35     0.678654   36.280856   61.344335       dct    BLIP    NaN
# 36     0.770075   41.487277   57.345106       dct    BLIP    NaN
# 37     0.876950   47.729710   52.845090       dct    BLIP    NaN
# 38     1.000000   55.143844   54.541527  baseline    BLIP    NaN
# 39     0.258001  168.936655   31.633972    PiToMe   BLIP2    0.0
# 40     0.332083  217.652470   26.430519    PiToMe   BLIP2    0.0
# 41     0.451615  296.935880   20.756965    PiToMe   BLIP2    0.0
# 42     0.654888  434.503588   15.016604    PiToMe   BLIP2    0.0
# 43     0.258001  168.936655   31.829895      ToMe   BLIP2    0.0
# 44     0.332083  217.652470   26.574952      ToMe   BLIP2    0.0
# 45     0.451615  296.935880   20.836981      ToMe   BLIP2    0.0
# 46     0.654888  434.503588   15.079097      ToMe   BLIP2    0.0
# 47     0.258001  168.936655   28.842277       dct   BLIP2    0.0
# 48     0.332083  217.652470   23.793039       dct   BLIP2    0.0
# 49     0.451615  296.935880   18.499270       dct   BLIP2    0.0
# 50     0.654888  434.503588   13.267891       dct   BLIP2    0.0
# 51     1.000000  678.451488   10.243517  baseline   BLIP2    0.0

# %%
df.loc[df['algo']=='none', 'algo'] = 'baseline'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, MultipleLocator
# Sample data
custom_marker = {'baseline':'o','PiToMe':'x', 'ToMe':'+', 'dct': 's'}
custom_color = {'baseline':'gray','PiToMe':'red', 'ToMe':'blue', 'dct': 'green'}

sns.set(style="darkgrid")
# Draw a line plot
sns.lineplot(
    x='gflops', 
    y='test/r_all', 
    style='model',
    hue='algo',
    data=df[df['algo'].isin(['PiToMe', 'ToMe','dct', 'baseline'])], 
    markers=True, 
    dashes=True,
    markersize=6,
    # markers=custom_marker,
    ci=None,  # Disable confidence intervals for a cleaner plot
    palette=custom_color,
    # label='algo'
)

plt.xscale('log')
# plt.yscale('log')
# plt.text(df.loc[df['algo'] == 'baseline', 'gflops'].values[0],
        #  df.loc[df['algo'] == 'baseline', 'test/r_all'].values[0],
        #  'CLIP-B',
        #  fontsize=12,
        #  color='black',
        #  ha='right', va='bottom')

# Add text to the plot
# plt.title('Comparison of Algorithms')
plt.xlabel('FLOPS')
plt.ylabel('Accuracy')
# Add gridlines
# plt.grid(color='gray', linestyle='--', linewidth=0.5)

# Format x-axis ticks to display actual values
plt.gca().xaxis.set_major_formatter(ScalarFormatter())
plt.gca().xaxis.set_major_locator(MultipleLocator(200))
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_38172/3375829124.py:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %%
import pandas as pd
df = pd.read_csv('/home/caduser/HDD/vit_token_compress/PiToMe/deit_ost.csv')

# %%
df

# %%
df.loc[df['flops'] < 1.5, 'model'] = 'DeiT-T-16' 
df.loc[(df['flops'] > 1.5) & (df['flops'] < 5.0), 'model'] = 'DeiT-S-16'

# %%
df

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, MultipleLocator
# Sample data
custom_marker = {'baseline':'o','PiToMe':'x', 'ToMe':'+', 'DiffRate': 's'}
custom_color = {'baseline':'gray','PiToMe':'red', 'ToMe':'blue', 'DiffRate': 'green'}

sns.set(style="darkgrid")
# Draw a line plot
sns.lineplot(
    x='flops', 
    y='acc1', 
    style='model',
    hue='algo',
    data=df[df['algo'].isin(['PiToMe', 'ToMe','DiffRate', 'baseline'])], 
    markers=True, 
    dashes=True,
    markersize=7,
    # markers=custom_marker,
    ci=None,  # Disable confidence intervals for a cleaner plot
    palette=custom_color,
    # label='algo'
)

plt.xscale('log')
# plt.yscale('log')
# plt.text(df.loc[df['algo'] == 'baseline', 'gflops'].values[0],
        #  df.loc[df['algo'] == 'baseline', 'test/r_all'].values[0],
        #  'CLIP-B',
        #  fontsize=12,
        #  color='black',
        #  ha='right', va='bottom')

# Add text to the plot
# plt.title('Comparison of Algorithms')
plt.xlabel('FLOPS')
plt.ylabel('Accuracy')
# Add gridlines
# plt.grid(color='gray', linestyle='--', linewidth=0.5)

# Format x-axis ticks to display actual values
plt.gca().xaxis.set_major_formatter(ScalarFormatter())
plt.gca().xaxis.set_major_locator(MultipleLocator(4))
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_38172/1603740458.py:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

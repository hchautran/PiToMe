# %%
import pandas as pd
df = pd.read_csv('/home/caduser/HDD/vit_token_compress/PiToMe/flickr_ots.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
custom_marker = {'none':'o','PiToMe':'x', 'ToMe':'+', 'dct': 's'}
custom_color = {'none':'gray','PiToMe':'red', 'ToMe':'blue', 'dct': 'green'}

# Draw a line plot
sns.lineplot(
    x='gflops', 
    y='test/r_all', 
    style='model',
    hue='algo',
    data=df[df['algo'].isin(['PiToMe', 'ToMe','dct'])], 
    markers=True, 
    # dashes=True,
    # markers=custom_marker,
    palette=custom_color,
)

sns.lineplot(
    x='gflops', 
    y='test/r_all', 
    style='model',
    hue='algo',
    data=df[df['algo']=='none'], 
    markers=True, 
    markersize=10,
    palette=custom_color,
)
# plt.xscale('log')
# plt.yscale('log')
# plt.text(df.loc[df['algo'] == 'baseline', 'gflops'].values[0],
        #  df.loc[df['algo'] == 'baseline', 'test/r_all'].values[0],
        #  'CLIP-B',
        #  fontsize=12,
        #  color='black',
        #  ha='right', va='bottom')

# Add text to the plot

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_22578/3445963131.py:21: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(

# %%
import pandas as pd
df = pd.read_csv('/home/caduser/HDD/vit_token_compress/PiToMe/deit_ost.csv')

# %%
df
# Out:
#     Unnamed: 0      flops      loss       acc1       acc5    img_per_s  \
# 0            0   1.080588  1.240591  71.697114  90.857620  4303.819238
# 1            0   0.923850  1.281416  70.990408  90.311806  4802.619571
# 2            0   0.801584  1.332893  69.915073  89.747663  5312.141237
# 3            0   0.694371  1.404492  68.540356  88.867844  5823.871034
# 4            0   0.612276  1.496213  66.644264  87.713081  6306.007474
# 5            0   0.533724  1.633492  63.982404  85.988065  6842.445256
# 6            0   1.064759  1.229350  72.051486  91.020549  4280.349583
# 7            0   0.911875  1.257689  71.711370  90.839290  4729.330842
# 8            0   0.787302  1.299357  70.929309  90.324026  5137.027577
# 9            0   0.685068  1.365773  69.617727  89.419767  5509.536494
# 10           0   0.600600  1.454913  67.739965  88.497179  5824.542655
# 11           0   0.530361  1.615645  64.850003  86.146922  6055.066357
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
custom_marker = {'none':'o','PiToMe':'x', 'ToMe':'+', 'DiffRate': 's'}
custom_color = {'none':'gray','PiToMe':'red', 'ToMe':'blue', 'DiffRate': 'green'}

# Draw a line plot
sns.lineplot(
    x='flops', 
    y='acc1', 
    style='model',
    hue='algo',
    data=df[df['algo'].isin(['PiToMe', 'ToMe','DiffRate'])], 
    markers=True, 
    # dashes=True,
    # markers=custom_marker,
    palette=custom_color,
)

sns.lineplot(
    x='flops', 
    y='acc1', 
    style='model',
    hue='algo',
    data=df[df['algo']=='none'], 
    markers=True, 
    markersize=10,
    palette=custom_color,
)
# plt.xscale('log')
# plt.yscale('log')
# plt.text(df.loc[df['algo'] == 'baseline', 'gflops'].values[0],
        #  df.loc[df['algo'] == 'baseline', 'test/r_all'].values[0],
        #  'CLIP-B',
        #  fontsize=12,
        #  color='black',
        #  ha='right', va='bottom')

# Add text to the plot

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_22578/3001237981.py:21: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(

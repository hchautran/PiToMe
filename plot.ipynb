# %%
import pandas as pd


path = '/home/caduser/HDD/vit_token_compress/PiToMe/train_tc_bert-base-uncased_imdb.csv'
df = pd.read_csv(path)

# %%
df
# Out:
#    dataset               model       algo     gflops   ratio        acc
# 0     imdb   bert-base-uncased       none  48.720006    0.80  93.713072
# 1     imdb   bert-base-uncased     pitome  25.340006    0.80  93.526072
# 2     imdb   bert-base-uncased       tome  25.278572    0.80  93.354127
# 3     imdb   bert-base-uncased       tofu  25.248752    0.80  93.360125
# 4     imdb   bert-base-uncased     pitome  21.132669    0.75  93.172185
# 5     imdb   bert-base-uncased       tome  21.046452    0.75  92.992242
# 6     imdb   bert-base-uncased       tofu  21.047385    0.75  93.022233
# 7     imdb   bert-base-uncased     pitome  17.583278    0.70  92.646353
# 8     imdb   bert-base-uncased       tome  17.581349    0.70  92.336452
# 9     imdb   bert-base-uncased       tofu  17.577013    0.70  92.348448
# 10    imdb   bert-base-uncased   diffrate  25.022904    0.80  92.962252
# 11    imdb   bert-base-uncased   diffrate  20.846770    0.75  92.534389
# ...

# %%
import seaborn as sns
import  matplotlib.pyplot as plt
print(df)
sns.lineplot(x='ratio', y='acc', data=df)

# Customize the plot (optional)
plt.title("Line Chart from Pandas Data")
plt.xlabel("gflops")
plt.ylabel("acc")
plt.xticks(rotation=45)  # Rotate x-axis labels for readability with many dates
plt.grid(True)  # Add gridlines for better visualization

# Show the plot
plt.show()
# Out:
#    dataset               model       algo     gflops   ratio        acc
# 0     imdb   bert-base-uncased       none  48.720006    0.80  93.713072
# 1     imdb   bert-base-uncased     pitome  25.340006    0.80  93.526072
# 2     imdb   bert-base-uncased       tome  25.278572    0.80  93.354127
# 3     imdb   bert-base-uncased       tofu  25.248752    0.80  93.360125
# 4     imdb   bert-base-uncased     pitome  21.132669    0.75  93.172185
# 5     imdb   bert-base-uncased       tome  21.046452    0.75  92.992242
# 6     imdb   bert-base-uncased       tofu  21.047385    0.75  93.022233
# 7     imdb   bert-base-uncased     pitome  17.583278    0.70  92.646353
# 8     imdb   bert-base-uncased       tome  17.581349    0.70  92.336452
# 9     imdb   bert-base-uncased       tofu  17.577013    0.70  92.348448
# 10    imdb   bert-base-uncased   diffrate  25.022904    0.80  92.962252
# 11    imdb   bert-base-uncased   diffrate  20.846770    0.75  92.534389
# ...
